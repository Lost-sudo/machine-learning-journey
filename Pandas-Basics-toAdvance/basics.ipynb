# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Pandas Basics

# %%
# Series
data = [10, 20, 30, 40]
s = pd.Series(data, index=['a', 'b', 'c', 'd'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='str')

# %%
s.values
# Out:
# array([10, 20, 30, 40])

# %%
# DataFrame
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "Salary": [50_000, 60_000, 70_000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='str')

# %%
df.head()
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      str
#  1   Age     3 non-null      int64
#  2   Salary  3 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 204.0 bytes

# %%
df.describe()
# Out:
#         Age   Salary
# count   3.0      3.0
# mean   30.0  60000.0
# std     5.0  10000.0
# min    25.0  50000.0
# 25%    27.5  55000.0
# 50%    30.0  60000.0
# 75%    32.5  65000.0
# max    35.0  70000.0

# %% [markdown]
# Indexiong and Selection

# %% [markdown]
# Column selection

# %%
df["Name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: str

# %%
df[["Name", "Age"]]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %% [markdown]
# Row selection

# %%
df.loc[0]   # by label/index
# Out:
# Name      Alice
# Age          25
# Salary    50000
# Name: 0, dtype: object

# %%
df.iloc[0]  # by position
# Out:
# Name      Alice
# Age          25
# Salary    50000
# Name: 0, dtype: object

# %% [markdown]
# Conditional selection

# %%
df[df["Age"] > 28]
# Out:
#       Name  Age  Salary
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %% [markdown]
# Adding or Removing Columns

# %%
df["Bonus"] = [5000, 6000, 7000]

# %%
df.drop("Salary", axis=1, inplace=True)

# %%
df
# Out:
#       Name  Age  Bonus
# 0    Alice   25   5000
# 1      Bob   30   6000
# 2  Charlie   35   7000

# %% [markdown]
# Handling Missing Data

# %%
df.isnull()
# Out:
#     Name    Age  Bonus
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False

# %%
df.dropna()
# Out:
#       Name  Age  Bonus
# 0    Alice   25   5000
# 1      Bob   30   6000
# 2  Charlie   35   7000

# %%
df.fillna(0)
# Out:
#       Name  Age  Bonus
# 0    Alice   25   5000
# 1      Bob   30   6000
# 2  Charlie   35   7000

# %% [markdown]
# Sorting

# %%
df.sort_values(by="Age", ascending=False)
# Out:
#       Name  Age  Bonus
# 2  Charlie   35   7000
# 1      Bob   30   6000
# 0    Alice   25   5000

# %%
df.sort_index()
# Out:
#       Name  Age  Bonus
# 0    Alice   25   5000
# 1      Bob   30   6000
# 2  Charlie   35   7000

# %% [markdown]
# Reading/Writing Files

# %%
df = pd.read_csv("../Datum/data.csv")

# %%
df
# Out:
#       Name  Age         City  Salary        Date
# 0     John   25     New York   50000  2026-01-01
# 1     Jane   30  Los Angeles   65000  2026-02-01
# 2      Bob   35      Chicago   55000  2026-03-01
# 3    Alice   28      Houston   52000  2026-04-01
# 4  Charlie   32      Phoenix   58000  2026-05-01

# %%
df.to_csv("../Datum/output.csv", index=False)

# %%
df.to_excel("../Datum/output.xlsx", index=False)

# %% [markdown]
# Operations

# %%
# Arithmetic operations are vectorized
df['Salary'] * 1.1
# Out:
# 0    55000.0
# 1    71500.0
# 2    60500.0
# 3    57200.0
# 4    63800.0
# Name: Salary, dtype: float64

# %%
# Apply functions
df["Age_plus_5"] = df["Age"].apply(lambda x: x + 5)

# %%
df
# Out:
#       Name  Age         City  Salary        Date  Age_plus_5
# 0     John   25     New York   50000  2026-01-01          30
# 1     Jane   30  Los Angeles   65000  2026-02-01          35
# 2      Bob   35      Chicago   55000  2026-03-01          40
# 3    Alice   28      Houston   52000  2026-04-01          33
# 4  Charlie   32      Phoenix   58000  2026-05-01          37

# %%
# Apply on rows
df["Info"] = df.apply(lambda row: f"{row["Name"]} ({row["Age"]})", axis=1)

# %%
df
# Out:
#       Name  Age         City  Salary        Date  Age_plus_5          Info
# 0     John   25     New York   50000  2026-01-01          30     John (25)
# 1     Jane   30  Los Angeles   65000  2026-02-01          35     Jane (30)
# 2      Bob   35      Chicago   55000  2026-03-01          40      Bob (35)
# 3    Alice   28      Houston   52000  2026-04-01          33    Alice (28)
# 4  Charlie   32      Phoenix   58000  2026-05-01          37  Charlie (32)

# %% [markdown]
# Grouping

# %%
data = {
    "Department": ["HR", "IT", "HR", "IT"],
    "Salary": [50_000, 60_000, 55_000, 65_000]
}
df = pd.DataFrame(data)

# %%
df.groupby("Department").mean()
# Out:
#              Salary
# Department
# HR          52500.0
# IT          62500.0

# %% [markdown]
# Merging and Joining

# %%
df1 = pd.DataFrame({"ID": [1, 2], "Name": ["Alice", "Bob"]})
df2 = pd.DataFrame({"ID": [1, 2], "Salary": [50_000, 60_000]})

# %%
pd.merge(df1, df2, on="ID", how="inner")
# Out:
#    ID   Name  Salary
# 0   1  Alice   50000
# 1   2    Bob   60000

# %% [markdown]
# Pivot Tables

# %%
df.pivot_table(values="Salary", index="Department", aggfunc="mean")
# Out:
#              Salary
# Department
# HR          52500.0
# IT          62500.0

# %% [markdown]
# Data and Time

# %%
dates = pd.to_datetime(["2026-01-01", "2026-02-01"])
df["Date"] = dates.repeat(2).values
df["Year"] = df["Date"].dt.year
df["Month"] = df["Date"].dt.month

# %%
df
# Out:
#   Department  Salary       Date  Year  Month
# 0         HR   50000 2026-01-01  2026      1
# 1         IT   60000 2026-01-01  2026      1
# 2         HR   55000 2026-02-01  2026      2
# 3         IT   65000 2026-02-01  2026      2

# %% [markdown]
# MultiIndex

# %%
arrays = [['HR','HR','IT','IT'], [1,2,1,2]]
index = pd.MultiIndex.from_arrays(arrays, names=('Dept','ID'))
df = pd.DataFrame({'Salary':[50000,55000,60000,65000]}, index=index)

# %%
df
# Out:
#          Salary
# Dept ID
# HR   1    50000
#      2    55000
# IT   1    60000
#      2    65000

# %% [markdown]
# Window Functions

# %%
df["Salary_Rolling"] = df["Salary"].rolling(window=2).mean()
df["Salary_Expanding"] = df["Salary"].expanding().mean()

# %%
df
# Out:
#          Salary  Salary_Rolling  Salary_Expanding
# Dept ID
# HR   1    50000             NaN           50000.0
#      2    55000         52500.0           52500.0
# IT   1    60000         57500.0           55000.0
#      2    65000         62500.0           57500.0

# %% [markdown]
# Categorial Data

# %%
df = df.reset_index()
df['Dept'] = df['Dept'].astype('category')

df['Dept'].cat.categories
df['Dept'].cat.codes
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# dtype: int8

# %% [markdown]
# Efficient Memory Usage

# %%
df["Salary"] = pd.to_numeric(df["Salary"], downcast="integer")
df
# Out:
#   Dept  ID  Salary  Salary_Rolling  Salary_Expanding
# 0   HR   1   50000             NaN           50000.0
# 1   HR   2   55000         52500.0           52500.0
# 2   IT   1   60000         57500.0           55000.0
# 3   IT   2   65000         62500.0           57500.0

# %%
df["Dept"] = df["Dept"].astype("category")
df
# Out:
#   Dept  ID  Salary  Salary_Rolling  Salary_Expanding
# 0   HR   1   50000             NaN           50000.0
# 1   HR   2   55000         52500.0           52500.0
# 2   IT   1   60000         57500.0           55000.0
# 3   IT   2   65000         62500.0           57500.0
