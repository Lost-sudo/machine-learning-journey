# %%
temperature = 29

if temperature > 30:
    print("It's a hot day!")
    print("It's time for cola")
elif temperature < 30:
    print("It's a nice day!")
elif temperature < 10:
    print("It's a cold day!")
else:
    print("Done")
# Out:
# It's a nice day!
