# %%
names = ["Elton", "Sam", "Bob", "Emma", 0, 0.1, True]

# %%
names
# Out:
# ['Elton', 'Sam', 'Bob', 'Emma', 0, 0.1, True]

# %%
names[-1]
# Out:
# True

# %%
names[-2]
# Out:
# 0.1

# %%
names[0:2]
# Out:
# ['Elton', 'Sam']

# %%
numbers = [1, 2, 3, 4, 5]

# %%
numbers.append(6)

# %%
numbers.insert(0, 0)

# %%
1 in numbers
# Out:
# True

# %%
numbers
# Out:
# [0, 1, 2, 3, 4, 5, 6]
