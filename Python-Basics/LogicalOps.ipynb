# %%
age = 5

# %%
age > 10 and age < 30
# Out:
# False

# %%
age > 10 or age < 30
# Out:
# True

# %%
not age > 10
# Out:
# True

# %%
# and (both true)
# or (atleast 1 true)
# not (inverse of a value)
