# %%
age = 40
temp = 35.8
name = "Lost"
is_offline = False
print(age)
print(temp)
print(name)
print(is_offline)
# Out:
# 40
# 35.8
# Lost
# False

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(type(temp))
# Out:
# <class 'float'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(is_offline))
# Out:
# <class 'bool'>

# %%
print(float(age))
# Out:
# 40.0

# %%
print("Age of xyz is " + str(age))
# Out:
# Age of xyz is 40
